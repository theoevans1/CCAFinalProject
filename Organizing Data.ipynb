# %%
import lucem_illud
import pandas

# %%
supernatural1_df = pandas.read_csv("./DataCSVs/supernatural_data.csv")
supernatural2_df = pandas.read_csv("./DataCSVs/supernatural_data2.csv")
supernatural3_df = pandas.read_csv("./DataCSVs/supernatural_data3.csv")

# %%
supernatural_df = supernatural1_df.append([supernatural2_df, supernatural3_df])
supernatural_df.to_csv('./DataCSVs/supernatural_full.csv', index=True)
supernatural_df
# Out:
#        work_id                                           title  \
# 0     29767170  screamin' at the cars, hey, i wanna get better
# 1     29713014                             How Many More Times
# 2     27095071                             Back Together Again
# 3     29652519                                      Three Days
# 4     29766396  Don't Think About: Dean Bottoming For Teen Sam
# ...        ...                                             ...
# 1304  21130412                       Do I deserve a good home?
# 1305  28931688                                      The Vision
# 1306  28931802                      Stay Frosty Royal Milk Tea
# 1307  28931172                                  With This Ring
# 1308  28931274                                   Pretty in Ink
#
#                                author                 rating         category  \
# 0                  ['sydneygremlins']      General Audiences              M/M
# ...

# %%
dw1_df = pandas.read_csv("./DataCSVs/doctor_who_data.csv")
dw2_df = pandas.read_csv("./DataCSVs/doctor_who_data2.csv")
dw3_df = pandas.read_csv("./DataCSVs/doctor_who_data3.csv")
dw4_df = pandas.read_csv("./DataCSVs/doctor_who_data4.csv")
dw5_df = pandas.read_csv("./DataCSVs/doctor_who_data5.csv")

# %%
dw_df = dw1_df.append([dw2_df, dw3_df, dw4_df, dw5_df])
dw_df.to_csv('./DataCSVs/doctor_who_full.csv', index=True)
dw_df
# Out:
#       work_id                                           title  \
# 0    29149296                               Cherchez La Femme
# 1    29765604                               Never Anyone Else
# 2    29763930                                 Tastes Like You
# 3    29763300                                       One Shots
# 4    29520195             the woods are lovely, dark and deep
# ..        ...                                             ...
# 287  26349580                                        Save Him
# 288  27616528                       The Princess of Gallifrey
# 289  27616265                                 A second ago...
# 290  27615749        you put your arms around me and I'm home
# 291  27612712  WhoNatural - Doctor Who/Supernatural Crossover
#
#                                           author                 rating  \
# 0                                   ['inkvvell']               Explicit
# 1                         ['ArcadeYouthUnknown']      General Audiences
# ...

# %%
sherlock1_df = pandas.read_csv("./DataCSVs/sherlock_data.csv")
sherlock2_df = pandas.read_csv("./DataCSVs/sherlock_data2.csv")
sherlock3_df = pandas.read_csv("./DataCSVs/sherlock_data3.csv")

# %%
sherlock_df = sherlock1_df.append([sherlock2_df, sherlock3_df])
sherlock_df.to_csv('./DataCSVs/sherlock_full.csv', index=True)
sherlock_df
# Out:
#       work_id                                              title  \
# 0    29764527                                  Tears in His Eyes
# 1    29764095               Yet Still More 20 Questions--Longing
# 2    29153631                           February is for Johnlock
# 3    29763786                                 Song of Our Hearts
# 4    27110074                             Who We Are in the Dark
# ..        ...                                                ...
# 515  27573244                              Another such accident
# 516  27567916                                    Only One Option
# 517  11295936  Jim Moriarty's Right and Left Hands: One for D...
# 518  27562648                                Take It So You Burn
# 519  24251764                     Cmon, Lets get you boys Holmes
#
#                                             author                 rating  \
# 0                               ['orphan_account']              Not Rated
# ...

# %%
star_trek1_df = pandas.read_csv("./DataCSVs/star_trek_data.csv")
star_trek2_df = pandas.read_csv("./DataCSVs/star_trek_data2.csv")
star_trek3_df = pandas.read_csv("./DataCSVs/star_trek_data3.csv")

# %%
star_trek_df = star_trek1_df.append([star_trek2_df, star_trek3_df])
star_trek_df.to_csv('./DataCSVs/star_trek_full.csv', index=True)
star_trek_df
# Out:
#        work_id                               title  \
# 0     29766600                   Shore Leave Plans
# 1     29766339                        adira adrift
# 2     29021172  The Twenty-Two-Minute Away Mission
# 3     29764719               Unplanned Valentine's
# 4     29764881                    The Holding Cell
# ...        ...                                 ...
# 1390  27101365                       The Offspring
# 1391  27499618                      The Contractor
# 1392  27578065                          Yesteryear
# 1393  26757109           Kinktober 2020 Pike/Tilly
# 1394  27575294                 Nervous Tick Motion
#
#                                 author                 rating  \
# 0                          ['reeby10']      General Audiences
# 1                  ['trillnaturalist']  Teen And Up Audiences
# 2                  ['GracefulCharity']  Teen And Up Audiences
# 3          ['lovemelizards (tomfics)']  Teen And Up Audiences
# ...

# %%
teen_wolf1_df = pandas.read_csv("./DataCSVs/teen_wolf_data.csv")
teen_wolf2_df = pandas.read_csv("./DataCSVs/teen_wolf_data2.csv")
teen_wolf3_df = pandas.read_csv("./DataCSVs/teen_wolf_data3.csv")
teen_wolf4_df = pandas.read_csv("./DataCSVs/teen_wolf_data4.csv")

# %%
teen_wolf_df = teen_wolf1_df.append([teen_wolf2_df, teen_wolf3_df, teen_wolf4_df])
teen_wolf_df.to_csv('./DataCSVs/teen_wolf_full.csv', index=True)
teen_wolf_df
# Out:
#       work_id                        title                 author  \
# 0    29764995             Too young to die              ['Dysia']
# 1    23852278                      Current            ['fuelfox']
# 2    28697721           If aught but death         ['bel_e_muir']
# 3    29513514             Make Your Choice    ['asarcasticwitch']
# 4    29758242            You're Pregnant?!  ['evangelineimagine']
# ..        ...                          ...                    ...
# 181  28751190              Bun in the Oven    ['TwilightDeviant']
# 182  28823937             Backstage Passes    ['Thorny_Rose_463']
# 183  28824252                     Jealousy         ['Roadtrip78']
# 184  25519909  Pack of Morons (Translated)       ['breannab_nun']
# 185  28824903                    snowed in     ['blindinglights']
#
#                     rating       category                              fandom  \
# 0    Teen And Up Audiences            M/M                      Teen Wolf (TV)
# ...

# %%
supernatural_df['series'] = 'Supernatural'
supernatural_df
# Out:
#        work_id                                           title  \
# 0     29767170  screamin' at the cars, hey, i wanna get better
# 1     29713014                             How Many More Times
# 2     27095071                             Back Together Again
# 3     29652519                                      Three Days
# 4     29766396  Don't Think About: Dean Bottoming For Teen Sam
# ...        ...                                             ...
# 1304  21130412                       Do I deserve a good home?
# 1305  28931688                                      The Vision
# 1306  28931802                      Stay Frosty Royal Milk Tea
# 1307  28931172                                  With This Ring
# 1308  28931274                                   Pretty in Ink
#
#                                author                 rating         category  \
# 0                  ['sydneygremlins']      General Audiences              M/M
# ...

# %%
dw_df['series'] = 'Doctor Who'

# %%
sherlock_df['series'] = 'Sherlock'

# %%
star_trek_df['series'] = 'Star Trek'

# %%
teen_wolf_df['series'] = 'Teen Wolf'

# %%
fanfic_stories = supernatural_df.append([dw_df, sherlock_df, star_trek_df, teen_wolf_df])
fanfic_stories
# Out:
#       work_id                                           title  \
# 0    29767170  screamin' at the cars, hey, i wanna get better
# 1    29713014                             How Many More Times
# 2    27095071                             Back Together Again
# 3    29652519                                      Three Days
# 4    29766396  Don't Think About: Dean Bottoming For Teen Sam
# ..        ...                                             ...
# 181  28751190                                 Bun in the Oven
# 182  28823937                                Backstage Passes
# 183  28824252                                        Jealousy
# 184  25519909                     Pack of Morons (Translated)
# 185  28824903                                       snowed in
#
#                               author                 rating         category  \
# 0                 ['sydneygremlins']      General Audiences              M/M
# ...

# %%
fanfic_stories.to_csv('fanfic_data.csv', index=True)
