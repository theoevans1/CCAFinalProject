# %%
import bs4
import requests
import unidecode

# %%
# %run ao3_work_ids.py "https://archiveofourown.org/works?utf8=%E2%9C%93&work_search%5Bsort_column%5D=kudos_count&work_search%5Bother_tag_names%5D=&work_search%5Bexcluded_tag_names%5D=&work_search%5Bcrossover%5D=F&work_search%5Bcomplete%5D=&work_search%5Bwords_from%5D=&work_search%5Bwords_to%5D=&work_search%5Bdate_from%5D=&work_search%5Bdate_to%5D=&work_search%5Bquery%5D=&work_search%5Blanguage_id%5D=&commit=Sort+and+Filter&tag_id=Doctor+Who" --num_to_retrieve 500 --out_csv doctor_who_five
# Out:
# processing...
#
# ........................

# %%
# %run ao3_get_fanfics.py doctor_who_five.csv --csv Doctor_Who_FicFive.csv --header 'Chrome/88.0.4324.146 (Macintosh; Intel Mac OS X 10.15.7); Theo Evans/University of Chicago/theoevans@uchicago.edu'
# Out:
# Writing a header row for the csv.
# Scraping  335149
# Done.
# Scraping  97380
# Done.
# Scraping  90471
# Done.
# Scraping  6218785
# Done.
# Scraping  582688
# Access Denied
# Scraping  1885128
# Access Denied
# Scraping  158803
# Access Denied
# Scraping  679634
# Access Denied
# Scraping  335139
# Access Denied
# Scraping  578475
# Access Denied
# Scraping  2638742
# Access Denied
# Scraping  1301371
# Access Denied
# Scraping  471497
# Access Denied
# Scraping  16327070
# Access Denied
# Scraping  9302429
# Access Denied
# Scraping  3634875
# Access Denied
# Scraping  217428
# Access Denied
# Scraping  1721582
# Access Denied
# Scraping  16380470
# Access Denied
# Scraping  1411891
# Access Denied
# Scraping  490953
# Access Denied
# Scraping  536174
# Access Denied
# Scraping  6791470
# Access Denied
# Scraping  1241638
# Access Denied
# Scraping  7881616
# Access Denied
# Scraping  16460423
# Access Denied
# Scraping  16490114
# Access Denied
# Scraping  1086427
# ...
